# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * Cities closer the equator have higher temperatures, as expected. As we move away from the equator, cities in the northern hemisphere see a greater decrease in temperature compared to the southern hemisphere.
# * Latitude does not seem to affect humidity levels. Perhaps with another study we can examine if cities closer to a body of water have higher humidity. There doesn't seem to be a strong relationship between latitude and cloudiness either.
# * Latitude does not affect wind speed either. A better study would be to examine the relationship between the city's altitude and windspeed.
# * A city's temperaure is heavily influenced by it's latitude. Humidity, cloudines, and wind speed are all driven by other factors.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from pprint import pprint


# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 626

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Sample of Json response from API Call
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

params = {"appid": api_key,
         "units": units,
         "q": "irvine"}

response = requests.get(url, params=params).json()
pprint(response)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 33.69, 'lon': -117.83},
#  'dt': 1541693460,
#  'id': 5359777,
#  'main': {'humidity': 87,
#           'pressure': 1016,
#           'temp': 62.17,
#           'temp_max': 66.02,
#           'temp_min': 57.2},
#  'name': 'Irvine',
#  'sys': {'country': 'US',
#          'id': 375,
#          'message': 0.0057,
#          'sunrise': 1541686645,
#          'sunset': 1541724744,
#          'type': 1},
#  'visibility': 4828,
#  'weather': [{'description': 'haze', 'icon': '50d', 'id': 721, 'main': 'Haze'},
#              {'description': 'mist', 'icon': '50d', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 20, 'speed': 3.36}}

# %%
#Create Dataframe
weather_df = pd.DataFrame({"City": cities})
weather_df["Country"] = ""
weather_df["Temperature (F)"] = ""
weather_df["Latitude"] = ""
weather_df["Longitude"] = ""
weather_df["Humidity (%)"] = ""
weather_df["Cloudiness (%)"] = ""
weather_df["Wind Speed (mph)"] = ""
weather_df.head()
# Out:
#             City Country Temperature (F) Latitude Longitude Humidity (%)  \
# 0       sidi ali
# 1     butaritari
# 2  leningradskiy
# 3         atuona
# 4       sisimiut
#
#   Cloudiness (%) Wind Speed (mph)
# 0
# 1
# 2
# 3
# 4

# %%
# Perform API Calls for each City
params = {"appid": api_key,
         "units": units,
         "q": ""}

weather = []

print("Beginning Data Retrieval")
print("----------------------------------")

for index, row in weather_df.iterrows():
    params["q"] = row.City
    print("Processing Record " + str(index + 1) + " of " + str(len(cities)) + " | " + row.City)
    response = requests.get(url, params=params).json()
    weather.append(response)
    
    try:
        weather_df.loc[index, "Country"] = response['sys']['country']
        weather_df.loc[index, "Temperature (F)"] = response['main']['temp']
        weather_df.loc[index, "Latitude"] = response['coord']['lat']
        weather_df.loc[index, "Longitude"] = response['coord']['lon']
        weather_df.loc[index, "Humidity (%)"] = response['main']['humidity']
        weather_df.loc[index, "Cloudiness (%)"] = response['clouds']['all']
        weather_df.loc[index, "Wind Speed (mph)"] = response['wind']['speed']
    except:
        print("City Not Found...Skipping...")
        
    
          
print("----------------------------------")
print("Data Retrieval Complete")
print("----------------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------------
# Processing Record 1 of 626 | sidi ali
# Processing Record 2 of 626 | butaritari
# Processing Record 3 of 626 | leningradskiy
# Processing Record 4 of 626 | atuona
# Processing Record 5 of 626 | sisimiut
# Processing Record 6 of 626 | rikitea
# Processing Record 7 of 626 | yellowknife
# Processing Record 8 of 626 | kostomuksha
# Processing Record 9 of 626 | taolanaro
# City Not Found...Skipping...
# Processing Record 10 of 626 | piopio
# Processing Record 11 of 626 | upernavik
# Processing Record 12 of 626 | wajid
# Processing Record 13 of 626 | kidal
# Processing Record 14 of 626 | ushuaia
# Processing Record 15 of 626 | kenai
# Processing Record 16 of 626 | zhangjiakou
# Processing Record 17 of 626 | east london
# Processing Record 18 of 626 | hermanus
# Processing Record 19 of 626 | dutlwe
# Processing Record 20 of 626 | bethel
# Processing Record 21 of 626 | carnarvon
# Processing Record 22 of 626 | mys shmidta
# City Not Found...Skipping...
# Processing Record 23 of 626 | airai
# Processing Record 24 of 626 | kapaa
# Processing Record 25 of 626 | basco
# Processing Record 26 of 626 | belmonte
# Processing Record 27 of 626 | victoria
# Processing Record 28 of 626 | huanren
# Processing Record 29 of 626 | amravati
# Processing Record 30 of 626 | cape town
# Processing Record 31 of 626 | zhuhai
# Processing Record 32 of 626 | norman wells
# Processing Record 33 of 626 | brae
# Processing Record 34 of 626 | kodiak
# Processing Record 35 of 626 | mandera
# Processing Record 36 of 626 | port elizabeth
# Processing Record 37 of 626 | vaitupu
# City Not Found...Skipping...
# Processing Record 38 of 626 | portland
# Processing Record 39 of 626 | carndonagh
# Processing Record 40 of 626 | mataura
# Processing Record 41 of 626 | saint-ambroise
# Processing Record 42 of 626 | palabuhanratu
# City Not Found...Skipping...
# Processing Record 43 of 626 | saint-philippe
# Processing Record 44 of 626 | tacna
# Processing Record 45 of 626 | grand-lahou
# Processing Record 46 of 626 | omboue
# Processing Record 47 of 626 | padang
# Processing Record 48 of 626 | nikolskoye
# Processing Record 49 of 626 | byron bay
# Processing Record 50 of 626 | crystal lake
# Processing Record 51 of 626 | suifenhe
# Processing Record 52 of 626 | isangel
# Processing Record 53 of 626 | diamantino
# Processing Record 54 of 626 | linxia
# Processing Record 55 of 626 | carutapera
# Processing Record 56 of 626 | busselton
# Processing Record 57 of 626 | arraial do cabo
# Processing Record 58 of 626 | meulaboh
# Processing Record 59 of 626 | tasiilaq
# Processing Record 60 of 626 | camacha
# Processing Record 61 of 626 | khatanga
# Processing Record 62 of 626 | fukue
# Processing Record 63 of 626 | fillan
# Processing Record 64 of 626 | dubna
# Processing Record 65 of 626 | ahuimanu
# Processing Record 66 of 626 | kaitangata
# Processing Record 67 of 626 | baker city
# Processing Record 68 of 626 | katsuura
# Processing Record 69 of 626 | saint george
# Processing Record 70 of 626 | mar del plata
# Processing Record 71 of 626 | vilcun
# Processing Record 72 of 626 | bambous virieux
# Processing Record 73 of 626 | marsh harbour
# Processing Record 74 of 626 | albany
# Processing Record 75 of 626 | souillac
# Processing Record 76 of 626 | port hardy
# Processing Record 77 of 626 | luang prabang
# Processing Record 78 of 626 | ancud
# Processing Record 79 of 626 | new norfolk
# Processing Record 80 of 626 | vaini
# Processing Record 81 of 626 | teacapan
# Processing Record 82 of 626 | muros
# Processing Record 83 of 626 | port alfred
# Processing Record 84 of 626 | blagoyevo
# Processing Record 85 of 626 | attawapiskat
# City Not Found...Skipping...
# Processing Record 86 of 626 | cidreira
# Processing Record 87 of 626 | kungurtug
# Processing Record 88 of 626 | wanning
# Processing Record 89 of 626 | bluff
# Processing Record 90 of 626 | barentsburg
# City Not Found...Skipping...
# Processing Record 91 of 626 | paamiut
# Processing Record 92 of 626 | san pedro
# Processing Record 93 of 626 | ostrovnoy
# Processing Record 94 of 626 | sujawal
# Processing Record 389 of 626 | soyo
# Processing Record 390 of 626 | moose factory
# Processing Record 391 of 626 | yulara
# Processing Record 392 of 626 | hede
# Processing Record 393 of 626 | chalchihuites
# Processing Record 394 of 626 | kahului
# Processing Record 395 of 626 | xapuri
# Processing Record 396 of 626 | grand river south east
# City Not Found...Skipping...
# Processing Record 397 of 626 | mutis
# Processing Record 398 of 626 | terrasini
# Processing Record 399 of 626 | makuyuni
# Processing Record 400 of 626 | pizarro
# Processing Record 401 of 626 | komsomolskiy
# Processing Record 402 of 626 | visnes
# Processing Record 403 of 626 | meyungs
# City Not Found...Skipping...
# Processing Record 404 of 626 | los llanos de aridane
# Processing Record 405 of 626 | korla
# City Not Found...Skipping...
# Processing Record 406 of 626 | kargil
# Processing Record 407 of 626 | rayachoti
# Processing Record 408 of 626 | sayyan
# Processing Record 409 of 626 | clyde river
# Processing Record 410 of 626 | wilmington
# Processing Record 411 of 626 | karaton
# Processing Record 412 of 626 | avera
# Processing Record 413 of 626 | takoradi
# Processing Record 414 of 626 | grand gaube
# Processing Record 415 of 626 | douglas
# Processing Record 416 of 626 | vazante
# Processing Record 417 of 626 | boyolangu
# Processing Record 418 of 626 | teeli
# Processing Record 419 of 626 | revda
# Processing Record 420 of 626 | port-gentil
# Processing Record 421 of 626 | monywa
# Processing Record 422 of 626 | aflu
# City Not Found...Skipping...
# Processing Record 423 of 626 | cirpan
# City Not Found...Skipping...
# Processing Record 424 of 626 | asau
# City Not Found...Skipping...
# Processing Record 425 of 626 | sao filipe
# Processing Record 426 of 626 | nuuk
# Processing Record 427 of 626 | coahuayana
# Processing Record 428 of 626 | hienghene
# Processing Record 429 of 626 | kruisfontein
# Processing Record 430 of 626 | kununurra
# Processing Record 431 of 626 | jalgaon
# Processing Record 432 of 626 | lakes entrance
# Processing Record 433 of 626 | shimoda
# Processing Record 434 of 626 | fairbanks
# Processing Record 435 of 626 | deputatskiy
# Processing Record 436 of 626 | wellington
# Processing Record 437 of 626 | noumea
# Processing Record 438 of 626 | te anau
# Processing Record 439 of 626 | talnakh
# Processing Record 440 of 626 | tasbuget
# City Not Found...Skipping...
# Processing Record 441 of 626 | coihaique
# Processing Record 442 of 626 | kijang
# Processing Record 443 of 626 | hami
# Processing Record 444 of 626 | lugovoy
# Processing Record 445 of 626 | barcelos
# Processing Record 446 of 626 | umm kaddadah
# Processing Record 447 of 626 | galle
# Processing Record 448 of 626 | acapulco
# Processing Record 449 of 626 | warwick
# Processing Record 450 of 626 | zhigansk
# Processing Record 451 of 626 | mentok
# City Not Found...Skipping...
# Processing Record 452 of 626 | datong
# Processing Record 453 of 626 | itaituba
# Processing Record 454 of 626 | bielsk podlaski
# Processing Record 455 of 626 | green river
# Processing Record 456 of 626 | kortemark
# Processing Record 457 of 626 | tumannyy
# City Not Found...Skipping...
# Processing Record 458 of 626 | qingquan
# Processing Record 459 of 626 | maniitsoq
# Processing Record 460 of 626 | colonia
# Processing Record 461 of 626 | ngunguru
# Processing Record 462 of 626 | ternate
# Processing Record 463 of 626 | gasa
# Processing Record 616 of 626 | sorland
# Processing Record 617 of 626 | kavieng
# Processing Record 618 of 626 | chama
# Processing Record 619 of 626 | cognac
# Processing Record 620 of 626 | dombarovskiy
# Processing Record 621 of 626 | matay
# Processing Record 622 of 626 | labytnangi
# Processing Record 623 of 626 | sikasso
# Processing Record 624 of 626 | talara
# Processing Record 625 of 626 | weinan
# Processing Record 626 of 626 | salinas
# ----------------------------------
# Data Retrieval Complete
# ----------------------------------

# %%
#Display Data frame after API calls are made
weather_df.head(10)
# Out:
#             City Country Temperature (F) Latitude Longitude Humidity (%)  \
# 0       sidi ali      DZ           70.58     36.1      0.42           69
# 1     butaritari      KI           85.61     3.07    172.79           99
# 2  leningradskiy      RU           13.79    69.38    178.42          100
# 3         atuona      PF           76.74     -9.8   -139.03          100
# 4       sisimiut      GL           -5.16    66.94    -53.67          100
# 5        rikitea      PF           71.79   -23.12   -134.97          100
# 6    yellowknife      CA            12.2    62.45   -114.38           85
# 7    kostomuksha      RU           34.67    64.59      30.6           98
# 8      taolanaro
# 9         piopio      CL            53.6   -42.79    -73.57           93
#
#   Cloudiness (%) Wind Speed (mph)
# 0              0              3.6
# 1             64            18.25
# 2             48             7.63
# 3            100             7.74
# 4              0             1.81
# 5              0             7.96
# 6             90            16.11
# 7             92              3.6
# 8
# 9             90              4.7

# %%
# Check data types
weather_df.dtypes
# Out:
# City                object
# Country             object
# Temperature (F)     object
# Latitude            object
# Longitude           object
# Humidity (%)        object
# Cloudiness (%)      object
# Wind Speed (mph)    object
# dtype: object

# %%
# convert objects to float
weather_df[["Temperature (F)", "Latitude", "Longitude", "Humidity (%)", "Cloudiness (%)", "Wind Speed (mph)"]] = weather_df[["Temperature (F)", "Latitude", "Longitude", "Humidity (%)", "Cloudiness (%)", "Wind Speed (mph)"]].apply(pd.to_numeric)
weather_df.dtypes
# Out:
# City                 object
# Country              object
# Temperature (F)     float64
# Latitude            float64
# Longitude           float64
# Humidity (%)        float64
# Cloudiness (%)      float64
# Wind Speed (mph)    float64
# dtype: object

# %%
#count to make sure all rows have data
weather_df.count()
# Out:
# City                626
# Country             626
# Temperature (F)     562
# Latitude            562
# Longitude           562
# Humidity (%)        562
# Cloudiness (%)      562
# Wind Speed (mph)    562
# dtype: int64

# %%
#remove cities that were skipped in API call
weather_df = weather_df.dropna(how="any")
weather_df.count()
# Out:
# City                562
# Country             562
# Temperature (F)     562
# Latitude            562
# Longitude           562
# Humidity (%)        562
# Cloudiness (%)      562
# Wind Speed (mph)    562
# dtype: int64

# %%
#output 
weather_df.to_csv(output_data_file)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Latitude"], weather_df["Temperature (F)"], s=weather_df["Temperature (F)"], alpha=0.5, marker="o", edgecolors="black")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.title("Latitude vs Temperature (F) on 9-8-2018")
plt.savefig("Graphs/Lat_vs_temp.png", dpi=200)
plt.show()
# Out:
# C:\Users\Karl\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\collections.py:902: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Latitude"], weather_df["Humidity (%)"], s=weather_df["Humidity (%)"], marker="o", alpha=0.5, edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(0, 110)
plt.title("Latitude vs Humidity (%) on 9-8-2018")
plt.savefig("Graphs/Lat_vs_Humidity.png", dpi=200)
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Latitude"], weather_df["Cloudiness (%)"], alpha=0.5, edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Latitide vs Cloudiness (%) on 9-8-2018")
plt.savefig("Graphs/Lat_vs_Cloudiness.png", dpi=200)
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Latitude"], weather_df["Wind Speed (mph)"], alpha=0.5, edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")
plt.title("Latitude vs Wind Speed (MPH) on 9-8-2018")
plt.savefig("Graphs/Lat_vs_WindSpeed.png", dpi=200)
plt.show()
